# %% [markdown]
# 연습문제 3

# %% [markdown]
# 연습문제 2의 (1) 번의 독립변수를 후진 제거법(backward elimination)을 통해 선정하고, 모형을
# 학습하여라. 생성된 모형으로 예측을 수행하고, 예측 성과를 MAE, RMSE, MAPE로 보고하라.

# %%
# boston.csv 불러오기

import pandas as pd
boston = pd.read_csv('data/boston.csv')

boston_train = boston.iloc[0:232]
boston_test = boston.iloc[233:332]

# %%
# 모든 독립변수로 모델 학습

import statsmodels.api as sm

x = boston_train[['crim','zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'black', 'lstat']]
y = boston_train['medv']
X = sm.add_constant(x)

model = sm.OLS(y,X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     117.4
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):           1.18e-90
# Time:                        04:31:08   Log-Likelihood:                -580.52
# No. Observations:                 232   AIC:                             1189.
# Df Residuals:                     218   BIC:                             1237.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -13.1220      5.525     -2.375      0.018     -24.011      -2.233
# ...

# %%
# p-value가 가장 큰 chas 제거

X=X.drop(['chas'],axis=1)
model=sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.875
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     127.4
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):           1.29e-91
# Time:                        04:31:08   Log-Likelihood:                -580.77
# No. Observations:                 232   AIC:                             1188.
# Df Residuals:                     219   BIC:                             1232.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -13.1417      5.518     -2.382      0.018     -24.017      -2.266
# ...

# %%
# p-value가 가장 큰 indus 제거

X=X.drop(['indus'],axis=1)
model=sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     139.2
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):           1.42e-92
# Time:                        04:31:08   Log-Likelihood:                -581.07
# No. Observations:                 232   AIC:                             1186.
# Df Residuals:                     220   BIC:                             1228.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -13.3065      5.509     -2.416      0.017     -24.163      -2.450
# ...

# %%
# p-value가 가장 큰 lstat 제거

X=X.drop(['lstat'],axis=1)
model=sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.874
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     152.8
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):           2.10e-93
# Time:                        04:31:09   Log-Likelihood:                -581.74
# No. Observations:                 232   AIC:                             1185.
# Df Residuals:                     221   BIC:                             1223.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -15.0873      5.280     -2.858      0.005     -25.493      -4.682
# ...

# %%
# p-value가 가장 큰 zn 제거

X=X.drop(['zn'],axis=1)
model=sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.873
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     169.6
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):           2.67e-94
# Time:                        04:31:09   Log-Likelihood:                -582.31
# No. Observations:                 232   AIC:                             1185.
# Df Residuals:                     222   BIC:                             1219.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -15.0082      5.280     -2.842      0.005     -25.414      -4.602
# ...

# %%
# p-value가 가장 큰 rad 제거
# black은 신뢰도 95%구간이 0에 걸치므로 유의

X=X.drop(['rad'],axis=1)
model=sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   medv   R-squared:                       0.872
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     190.0
# Date:                Thu, 11 Jun 2020   Prob (F-statistic):           4.42e-95
# Time:                        04:31:09   Log-Likelihood:                -583.21
# No. Observations:                 232   AIC:                             1184.
# Df Residuals:                     223   BIC:                             1215.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -15.6590      5.266     -2.974      0.003     -26.036      -5.282
# ...

# %%
# 생성된 모형으로 예측 수행

import math
x_test = boston_test[['crim', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'black']]
y_test = boston_test['medv']
X_test = sm.add_constant(x_test)

test_prediction = model.predict(X_test)

# %%
# 예측 성과 보고

mae = sum( abs(test_prediction - y_test) / len(test_prediction))
rmse = math.sqrt( sum((test_prediction - y_test)**2) / len(test_prediction) )
mape = ((abs(test_prediction - y_test)/y_test)*100).mean()
print('MAE : ', mae)
print('RMSE : ', rmse)
print('MAPE : ', mape)
# Out:
# MAE :  17.083878635489285
# RMSE :  25.33123331948874
# MAPE :  157.3322090355051
